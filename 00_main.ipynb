# %% [markdown]
# <a href="https://colab.research.google.com/github/Willian2003/previsao-da-qualidade-do-sono/blob/main/00_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %run 01_eda.ipynb
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
# %run 02_preprocessing.ipynb
# Out:
#   Gender  Age            Occupation  Sleep Duration  Quality  Activity  \
# 0   Male   27     Software Engineer             6.1        6        42
# 1   Male   28                Doctor             6.2        6        60
# 2   Male   28                Doctor             6.2        6        60
# 3   Male   28  Sales Representative             5.9        4        30
# 4   Male   28  Sales Representative             5.9        4        30
#
#    Stress Level         BMI  Heart Rate  Steps  Pressure_Systolic  \
# 0             6  Overweight          77   4200                126
# 1             8      Normal          75  10000                125
# 2             8      Normal          75  10000                125
# 3             8       Obese          85   3000                140
# 4             8       Obese          85   3000                140
#
#    Pressure_Diastolic
# 0                  83
# 1                  80
# 2                  80
# 3                  90
# 4                  90

# %%
# %run 03_training.ipynb
# Out:
# Resultados Regressão Linear:
#        RMSE_teste  MAE_teste   R2_teste  RMSE_treino  R2_treino
# count   20.000000  20.000000  20.000000    20.000000  20.000000
# mean     0.283377   0.162568   0.942721     0.217927   0.966362
# std      0.051447   0.022017   0.020941     0.009843   0.003023
# min      0.200808   0.117211   0.888390     0.195110   0.960905
# 25%      0.253663   0.151811   0.931089     0.211574   0.964154
# 50%      0.275583   0.161812   0.946085     0.217805   0.965807
# 75%      0.304374   0.174243   0.958788     0.225389   0.968552
# max      0.389958   0.206722   0.975118     0.232328   0.972267
# Resultados Árvore de Decisão:
#        RMSE_teste  MAE_teste   R2_teste  RMSE_treino  R2_treino
# count   20.000000  20.000000  20.000000    20.000000  20.000000
# mean     0.262665   0.080136   0.950377     0.160174   0.981578
# std      0.064315   0.023604   0.021074     0.020317   0.004678
# min      0.156225   0.035758   0.907253     0.123133   0.973561
# ...

# %%
# %run 04_evaluation.ipynb
# Out:
# Comparação de desempenho médio entre os modelos:
#               Modelo  RMSE_teste_médio  RMSE_teste_std  MAE_teste_médio  \
# 0   Regressão Linear          0.283377        0.051447         0.162568
# 1  Árvore de Decisão          0.262665        0.064315         0.080136
# 2      Random Forest          0.272386        0.070976         0.122561
#
#    R2_teste_médio
# 0        0.942721
# 1        0.950377
# 2        0.947256
# Comparação de overfitting entre treino e teste:
#               Modelo  RMSE_treino  RMSE_teste  R2_treino  R2_teste
# 0   Regressão Linear     0.217927    0.283377   0.966362  0.942721
# 1  Árvore de Decisão     0.160174    0.262665   0.981578  0.950377
# 2      Random Forest     0.223739    0.272386   0.964491  0.947256

# %%
# %run 05_inference.ipynb
novo_paciente = criar_paciente(
    model=model,
    age=30,
    sleep_duration=7,
    activity=60,
    stress=2,
    heart_rate=78,
    steps=5000,
    systolic=120,
    diastolic=75,
    gender="Male", # "Male" = Homem | "Female" = Mulher
    bmi="Normal", # "Normal" = peso normal | "Overweight" = sobrepeso | "Obese" = obesidade
    occupation="Lawyer"
)

# occupation="Doctor"              # Médico
# occupation="Engineer"            # Engenheiro
# occupation="Lawyer"              # Advogado
# occupation="Manager"             # Gerente
# occupation="Nurse"               # Enfermeiro(a)
# occupation="Sales Representative"# Representante de vendas
# occupation="Salesperson"         # Vendedor(a)
# occupation="Scientist"           # Cientista
# occupation="Software Engineer"   # Engenheiro de software
# occupation="Teacher"             # Professor(a)

predicao = model.predict(novo_paciente)
predicao
# Out:
# no stored variable or alias novo_paciente
# /usr/local/lib/python3.12/dist-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# array([7.11046548])
